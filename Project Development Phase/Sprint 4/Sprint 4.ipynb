# %%
from google.colab import files
files.upload()

# %%
import pandas as pd
df = pd.read_csv('JC-20161-citibike-tripdata.csv') 
df.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            362  2016-01-01 00:02:52  2016-01-01 00:08:54              3186
# 1            200  2016-01-01 00:18:22  2016-01-01 00:21:42              3186
# 2            202  2016-01-01 00:18:25  2016-01-01 00:21:47              3186
# 3            248  2016-01-01 00:23:13  2016-01-01 00:27:21              3209
# 4            903  2016-01-01 01:03:20  2016-01-01 01:18:24              3195
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0      Grove St PATH               40.719586               -74.043117
# 1      Grove St PATH               40.719586               -74.043117
# 2      Grove St PATH               40.719586               -74.043117
# 3       Brunswick St               40.724176               -74.050656
# 4            Sip Ave               40.730743               -74.063784
#
#    End Station ID End Station Name  End Station Latitude  \
# 0            3209     Brunswick St             40.724176
# 1            3213   Van Vorst Park             40.718489
# 2            3213   Van Vorst Park             40.718489
# 3            3203    Hamilton Park             40.727596
# 4            3210   Pershing Field             40.742677
#
#    End Station Longitude  Bike ID   User Type  Birth Year  Gender
# 0             -74.050656    24647  Subscriber      1964.0       2
# 1             -74.047727    24605  Subscriber      1962.0       1
# 2             -74.047727    24689  Subscriber      1962.0       2
# 3             -74.044247    24693  Subscriber      1984.0       1
# 4             -74.051789    24573    Customer         NaN       0

# %%
temp = df

# %%
temp.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            362  2016-01-01 00:02:52  2016-01-01 00:08:54              3186
# 1            200  2016-01-01 00:18:22  2016-01-01 00:21:42              3186
# 2            202  2016-01-01 00:18:25  2016-01-01 00:21:47              3186
# 3            248  2016-01-01 00:23:13  2016-01-01 00:27:21              3209
# 4            903  2016-01-01 01:03:20  2016-01-01 01:18:24              3195
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0      Grove St PATH               40.719586               -74.043117
# 1      Grove St PATH               40.719586               -74.043117
# 2      Grove St PATH               40.719586               -74.043117
# 3       Brunswick St               40.724176               -74.050656
# 4            Sip Ave               40.730743               -74.063784
#
#    End Station ID End Station Name  End Station Latitude  \
# 0            3209     Brunswick St             40.724176
# 1            3213   Van Vorst Park             40.718489
# 2            3213   Van Vorst Park             40.718489
# 3            3203    Hamilton Park             40.727596
# 4            3210   Pershing Field             40.742677
#
#    End Station Longitude  Bike ID   User Type  Birth Year  Gender
# 0             -74.050656    24647  Subscriber      1964.0       2
# 1             -74.047727    24605  Subscriber      1962.0       1
# 2             -74.047727    24689  Subscriber      1962.0       2
# 3             -74.044247    24693  Subscriber      1984.0       1
# 4             -74.051789    24573    Customer         NaN       0

# %%
temp.describe()
# Out:
#        Trip Duration  Start Station ID  Start Station Latitude  \
# count   7.479000e+03       7479.000000             7479.000000
# mean    8.760840e+02       3199.060035               40.723892
# std     1.877094e+04         11.158335                0.007836
# min     6.100000e+01       3183.000000               40.697030
# 25%     2.360000e+02       3186.000000               40.718489
# 50%     3.610000e+02       3199.000000               40.723659
# 75%     5.780000e+02       3209.000000               40.727596
# max     1.569765e+06       3225.000000               40.752559
#
#        Start Station Longitude  End Station ID  End Station Latitude  \
# count              7479.000000     7479.000000           7479.000000
# mean                -74.046672     3196.959888             40.723235
# std                   0.011177       32.764969              0.007745
# min                 -74.096937      534.000000             40.697030
# 25%                 -74.050656     3186.000000             40.718489
# 50%                 -74.044247     3195.000000             40.721124
# 75%                 -74.036486     3209.000000             40.727596
# max                 -74.032108     3225.000000             40.752559
#
#        End Station Longitude       Bike ID   Birth Year       Gender
# count            7479.000000   7479.000000  7177.000000  7479.000000
# mean              -74.045822  24545.918171  1978.285356     1.155903
# std                 0.011177    176.014069     9.688657     0.462590
# min               -74.096937  17941.000000  1941.000000     0.000000
# 25%               -74.050656  24454.000000  1973.000000     1.000000
# 50%               -74.043845  24559.000000  1980.000000     1.000000
# 75%               -74.036486  24640.000000  1985.000000     1.000000
# max               -74.012723  24724.000000  1998.000000     2.000000

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7479 entries, 0 to 7478
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Trip Duration            7479 non-null   int64
#  1   Start Time               7479 non-null   object
#  2   Stop Time                7479 non-null   object
#  3   Start Station ID         7479 non-null   int64
#  4   Start Station Name       7479 non-null   object
#  5   Start Station Latitude   7479 non-null   float64
#  6   Start Station Longitude  7479 non-null   float64
#  7   End Station ID           7479 non-null   int64
#  8   End Station Name         7479 non-null   object
#  9   End Station Latitude     7479 non-null   float64
#  10  End Station Longitude    7479 non-null   float64
#  11  Bike ID                  7479 non-null   int64
#  12  User Type                7479 non-null   object
#  13  Birth Year               7177 non-null   float64
#  14  Gender                   7479 non-null   int64
# dtypes: float64(5), int64(5), object(5)
# memory usage: 876.6+ KB

# %%
temp["Start Time"] = pd.to_datetime(temp["Start Time"])
temp["Stop Time"] = pd.to_datetime(temp["Stop Time"])
temp.info()
temp["Hour"] = temp["Stop Time"].dt.hour - temp["Start Time"].dt.hour
temp.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7479 entries, 0 to 7478
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Trip Duration            7479 non-null   int64
#  1   Start Time               7479 non-null   datetime64[ns]
#  2   Stop Time                7479 non-null   datetime64[ns]
#  3   Start Station ID         7479 non-null   int64
#  4   Start Station Name       7479 non-null   object
#  5   Start Station Latitude   7479 non-null   float64
#  6   Start Station Longitude  7479 non-null   float64
#  7   End Station ID           7479 non-null   int64
#  8   End Station Name         7479 non-null   object
#  9   End Station Latitude     7479 non-null   float64
#  10  End Station Longitude    7479 non-null   float64
#  11  Bike ID                  7479 non-null   int64
#  12  User Type                7479 non-null   object
#  13  Birth Year               7177 non-null   float64
#  14  Gender                   7479 non-null   int64
# dtypes: datetime64[ns](2), float64(5), int64(5), object(3)
# memory usage: 876.6+ KB
#    Trip Duration          Start Time           Stop Time  Start Station ID  \
# 0            362 2016-01-01 00:02:52 2016-01-01 00:08:54              3186
# 1            200 2016-01-01 00:18:22 2016-01-01 00:21:42              3186
# 2            202 2016-01-01 00:18:25 2016-01-01 00:21:47              3186
# 3            248 2016-01-01 00:23:13 2016-01-01 00:27:21              3209
# 4            903 2016-01-01 01:03:20 2016-01-01 01:18:24              3195
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0      Grove St PATH               40.719586               -74.043117
# 1      Grove St PATH               40.719586               -74.043117
# 2      Grove St PATH               40.719586               -74.043117
# 3       Brunswick St               40.724176               -74.050656
# 4            Sip Ave               40.730743               -74.063784
#
#    End Station ID End Station Name  End Station Latitude  \
# 0            3209     Brunswick St             40.724176
# 1            3213   Van Vorst Park             40.718489
# 2            3213   Van Vorst Park             40.718489
# 3            3203    Hamilton Park             40.727596
# 4            3210   Pershing Field             40.742677
#
#    End Station Longitude  Bike ID   User Type  Birth Year  Gender  Hour
# 0             -74.050656    24647  Subscriber      1964.0       2     0
# 1             -74.047727    24605  Subscriber      1962.0       1     0
# 2             -74.047727    24689  Subscriber      1962.0       2     0
# 3             -74.044247    24693  Subscriber      1984.0       1     0
# 4             -74.051789    24573    Customer         NaN       0     0

# %%
temp.shape
# Out:
# (7479, 16)

# %%
temp['Age'] = 2022 - temp['Birth Year']
temp.head()
# Out:
#    Trip Duration          Start Time           Stop Time  Start Station ID  \
# 0            362 2016-01-01 00:02:52 2016-01-01 00:08:54              3186
# 1            200 2016-01-01 00:18:22 2016-01-01 00:21:42              3186
# 2            202 2016-01-01 00:18:25 2016-01-01 00:21:47              3186
# 3            248 2016-01-01 00:23:13 2016-01-01 00:27:21              3209
# 4            903 2016-01-01 01:03:20 2016-01-01 01:18:24              3195
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0      Grove St PATH               40.719586               -74.043117
# 1      Grove St PATH               40.719586               -74.043117
# 2      Grove St PATH               40.719586               -74.043117
# 3       Brunswick St               40.724176               -74.050656
# 4            Sip Ave               40.730743               -74.063784
#
#    End Station ID End Station Name  End Station Latitude  \
# 0            3209     Brunswick St             40.724176
# 1            3213   Van Vorst Park             40.718489
# 2            3213   Van Vorst Park             40.718489
# 3            3203    Hamilton Park             40.727596
# 4            3210   Pershing Field             40.742677
#
#    End Station Longitude  Bike ID   User Type  Birth Year  Gender  Hour   Age
# 0             -74.050656    24647  Subscriber      1964.0       2     0  58.0
# 1             -74.047727    24605  Subscriber      1962.0       1     0  60.0
# 2             -74.047727    24689  Subscriber      1962.0       2     0  60.0
# 3             -74.044247    24693  Subscriber      1984.0       1     0  38.0
# 4             -74.051789    24573    Customer         NaN       0     0   NaN

# %%
Age_Groups = ["<20", "20-29", "30-39", "40-49", "50-59", "60+"]
Age_Groups_Limits = [0, 20, 30, 40, 50, 60, np.inf]
Age_Min = 0
Age_Max = 100
temp["Age_group"] = pd.cut(temp["Age"], Age_Groups_Limits, labels=Age_Groups)
temp.head()
# Out:
#    Trip Duration          Start Time           Stop Time  Start Station ID  \
# 0            362 2016-01-01 00:02:52 2016-01-01 00:08:54              3186
# 1            200 2016-01-01 00:18:22 2016-01-01 00:21:42              3186
# 2            202 2016-01-01 00:18:25 2016-01-01 00:21:47              3186
# 3            248 2016-01-01 00:23:13 2016-01-01 00:27:21              3209
# 4            903 2016-01-01 01:03:20 2016-01-01 01:18:24              3195
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0      Grove St PATH               40.719586               -74.043117
# 1      Grove St PATH               40.719586               -74.043117
# 2      Grove St PATH               40.719586               -74.043117
# 3       Brunswick St               40.724176               -74.050656
# 4            Sip Ave               40.730743               -74.063784
#
#    End Station ID End Station Name  End Station Latitude  \
# 0            3209     Brunswick St             40.724176
# 1            3213   Van Vorst Park             40.718489
# 2            3213   Van Vorst Park             40.718489
# 3            3203    Hamilton Park             40.727596
# 4            3210   Pershing Field             40.742677
#
#    End Station Longitude  Bike ID   User Type  Birth Year  Gender  Hour   Age  \
# 0             -74.050656    24647  Subscriber      1964.0       2     0  58.0
# 1             -74.047727    24605  Subscriber      1962.0       1     0  60.0
# 2             -74.047727    24689  Subscriber      1962.0       2     0  60.0
# 3             -74.044247    24693  Subscriber      1984.0       1     0  38.0
# 4             -74.051789    24573    Customer         NaN       0     0   NaN
#
#   Age_group
# 0     50-59
# 1     50-59
# 2     50-59
# 3     30-39
# 4       NaN

# %%
trips_df = pd.DataFrame()
trips_df = temp.groupby(['Start Station Name','End Station Name']).size().reset_index(name = 'Number of Trips')
trips_df = trips_df.sort_values('Number of Trips',ascending = False)
trips_df["Start Station Name"] = trips_df["Start Station Name"].astype(str)
trips_df["End Station Name"] = trips_df["End Station Name"].astype(str)
trips_df["Routes"] = trips_df["Start Station Name"] + " to " + trips_df["End Station Name"]
trips_df = trips_df[:50]
trips_df = trips_df.reset_index()
trips_df
# Out:
#     index  Start Station Name    End Station Name  Number of Trips  \
# 0     199       Hamilton Park       Grove St PATH              272
# 1      50        Brunswick St       Grove St PATH              268
# 2     517      Van Vorst Park       Grove St PATH              240
# 3     318     McGinley Square             Sip Ave              208
# 4     172       Grove St PATH        Brunswick St              186
# 5     126    Essex Light Rail      Exchange Place              174
# 6     143      Exchange Place    Essex Light Rail              170
# 7     192       Grove St PATH      Van Vorst Park              167
# 8     492             Sip Ave     McGinley Square              166
# 9     180       Grove St PATH       Hamilton Park              161
# 10    362        Newport PATH       Hamilton Park              140
# 11    491             Sip Ave        Lincoln Park              125
# 12    206       Hamilton Park        Newport PATH              115
# 13    387        Newport Pkwy        Newport PATH               91
# 14    369        Newport PATH        Newport Pkwy               82
# 15    176       Grove St PATH    Essex Light Rail               79
# 16    295        Lincoln Park             Sip Ave               77
# 17    498             Sip Ave      Pershing Field               75
# 18    127    Essex Light Rail       Grove St PATH               75
# 19    515      Van Vorst Park      Exchange Place               64
# 20    375        Newport PATH           Warren St               62
# 21    460      Pershing Field             Sip Ave               60
# 22    535           Warren St       Grove St PATH               58
# 23    486             Sip Ave              Dey St               58
# 24    268  Liberty Light Rail       Grove St PATH               55
# 25    333          Newark Ave       Grove St PATH               53
# 26    534           Warren St      Exchange Place               51
# 27    388        Newport Pkwy        Newport Pkwy               50
# 28    193       Grove St PATH           Warren St               50
# 29    326          Newark Ave        Brunswick St               48
# 30    424         Oakland Ave             Sip Ave               47
# 31    131    Essex Light Rail        Newport PATH               46
# 32    197       Hamilton Park      Exchange Place               46
# 33    255   JC Medical Center       Grove St PATH               45
# 34    360        Newport PATH      Exchange Place               44
# 35    186       Grove St PATH          Newark Ave               44
# 36    359        Newport PATH    Essex Light Rail               44
# 37    155      Exchange Place        Newport PATH               42
# 38    496             Sip Ave         Oakland Ave               42
# 39    147      Exchange Place       Hamilton Park               41
# 40    183       Grove St PATH   JC Medical Center               41
# 41    334          Newark Ave       Hamilton Park               41
# 42    205       Hamilton Park          Newark Ave               41
# 43     80     Christ Hospital       Grove St PATH               40
# 44    122              Dey St             Sip Ave               39
# 45    184       Grove St PATH  Liberty Light Rail               38
# 46    381        Newport Pkwy      Exchange Place               38
# 47    161      Exchange Place      Van Vorst Park               35
# 48    162      Exchange Place           Warren St               35
# 49    332          Newark Ave      Exchange Place               35
#
#                                  Routes
# 0        Hamilton Park to Grove St PATH
# 1         Brunswick St to Grove St PATH
# 2       Van Vorst Park to Grove St PATH
# 3            McGinley Square to Sip Ave
# 4         Grove St PATH to Brunswick St
# 5    Essex Light Rail to Exchange Place
# 6    Exchange Place to Essex Light Rail
# 7       Grove St PATH to Van Vorst Park
# 8            Sip Ave to McGinley Square
# 9        Grove St PATH to Hamilton Park
# 10        Newport PATH to Hamilton Park
# 11              Sip Ave to Lincoln Park
# 12        Hamilton Park to Newport PATH
# 13         Newport Pkwy to Newport PATH
# 14         Newport PATH to Newport Pkwy
# 15    Grove St PATH to Essex Light Rail
# 16              Lincoln Park to Sip Ave
# 17            Sip Ave to Pershing Field
# 18    Essex Light Rail to Grove St PATH
# 19     Van Vorst Park to Exchange Place
# 20            Newport PATH to Warren St
# 21            Pershing Field to Sip Ave
# 22           Warren St to Grove St PATH
# 23                    Sip Ave to Dey St
# 24  Liberty Light Rail to Grove St PATH
# 25          Newark Ave to Grove St PATH
# 26          Warren St to Exchange Place
# 27         Newport Pkwy to Newport Pkwy
# 28           Grove St PATH to Warren St
# 29           Newark Ave to Brunswick St
# 30               Oakland Ave to Sip Ave
# 31     Essex Light Rail to Newport PATH
# 32      Hamilton Park to Exchange Place
# 33   JC Medical Center to Grove St PATH
# 34       Newport PATH to Exchange Place
# 35          Grove St PATH to Newark Ave
# 36     Newport PATH to Essex Light Rail
# 37       Exchange Place to Newport PATH
# 38               Sip Ave to Oakland Ave
# 39      Exchange Place to Hamilton Park
# 40   Grove St PATH to JC Medical Center
# 41          Newark Ave to Hamilton Park
# 42          Hamilton Park to Newark Ave
# 43     Christ Hospital to Grove St PATH
# 44                    Dey St to Sip Ave
# 45  Grove St PATH to Liberty Light Rail
# 46       Newport Pkwy to Exchange Place
# 47     Exchange Place to Van Vorst Park
# 48          Exchange Place to Warren St
# 49         Newark Ave to Exchange Place

# %%
px.pie(values = temp['Gender'].value_counts(),
       names =temp['Gender'].value_counts().index,
       title ="Gender Variation")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0e34010a-3799-44af-b847-0dba372ac869" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e34010a-3799-44af-b847-0dba372ac869")) {                    Plotly.newPlot(                        "0e34010a-3799-44af-b847-0dba372ac869",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":[1,2,0],"legendgroup":"","name":"","showlegend":true,"values":[5697,1474,308],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"color ...

# %%
px.bar(x=temp["Start Station Name"].value_counts().index,
       y=temp["Start Station Name"].value_counts().values,
       labels={'x':'Start Station Name',"y":"Count"})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="009bbe10-374c-4505-9f00-0f11a4e1c8cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("009bbe10-374c-4505-9f00-0f11a4e1c8cb")) {                    Plotly.newPlot(                        "009bbe10-374c-4505-9f00-0f11a4e1c8cb",                        [{"alignmentgroup":"True","hovertemplate":"Start Station Name=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Grove St PATH","Hamilton Park","Sip Ave","Exchange Place","Newport PATH","Van Vorst Park","Brunswick St","Essex Light Rail","Newark Ave","McGinley Square","Newport Pkwy","Warren St","Paulus Hook","City Hall","Pershing Field","Christ Hospital","Liberty Light Rail","Oakland Ave","JC Medical Center","Baldwin at Montgomery","5 Corners Library","Lincoln Park","Hilltop","Riverview Park","Dey St","Central Ave","Heights Elevator","North St","Garfield Ave Station","NJCU","Union St","Bayside Park","MLK Light Rail","Columbia Park","West Side Light Rail"],"xaxis":"x","y":[908,639,606,533,489,461,444,385,346,295,288,278,227,215,179,140,137,126,112,106,97,95,81,67,65,44,33,26,25,12,7,6,3,3,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale ...

# %%
px.bar(x=temp["End Station Name"].value_counts().index,
       y=temp["End Station Name"].value_counts().values,
       labels={'x':'End Station Name',"y":"Count"})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="cc5bdb37-d9d0-47fd-8f8f-cca3c27d801a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc5bdb37-d9d0-47fd-8f8f-cca3c27d801a")) {                    Plotly.newPlot(                        "cc5bdb37-d9d0-47fd-8f8f-cca3c27d801a",                        [{"alignmentgroup":"True","hovertemplate":"End Station Name=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Grove St PATH","Exchange Place","Hamilton Park","Sip Ave","Newport PATH","Essex Light Rail","Brunswick St","Van Vorst Park","Newark Ave","Warren St","Newport Pkwy","Paulus Hook","City Hall","McGinley Square","Pershing Field","Lincoln Park","Liberty Light Rail","JC Medical Center","Oakland Ave","Christ Hospital","Dey St","Baldwin at Montgomery","5 Corners Library","Riverview Park","Hilltop","Heights Elevator","Central Ave","North St","Garfield Ave Station","NJCU","Union St","West Side Light Rail","Bayside Park","MLK Light Rail","Columbia Park","Water - Whitehall Plaza"],"xaxis":"x","y":[1306,661,551,551,461,403,372,363,312,290,283,250,236,196,178,157,134,116,102,100,83,67,62,44,42,41,39,30,21,8,6,5,3,3,2,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth" ...

# %%
px.bar(x=temp["Hour"].value_counts().index,
       y=temp["Hour"].value_counts().values,
       title = "Hour usage of Citi Bikes",
       labels={'x':'Time',"y":"Number of people using bike"})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="867f27e6-2293-4dad-94d3-ae0723ca0670" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("867f27e6-2293-4dad-94d3-ae0723ca0670")) {                    Plotly.newPlot(                        "867f27e6-2293-4dad-94d3-ae0723ca0670",                        [{"alignmentgroup":"True","hovertemplate":"Time=%{x}<br>Number of people using bike=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[0,1,-23,2,4,3,-8,-13,-3,10,-10,-17,-9,-5,6,-11],"xaxis":"x","y":[6448,983,16,11,6,4,2,1,1,1,1,1,1,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"t ...
